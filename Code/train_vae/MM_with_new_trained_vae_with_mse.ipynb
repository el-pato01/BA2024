# %%
from get_models import Progress_Bar, Encoder, Decoder, CovarianceMatrix, thermometer_encode_df

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions.normal import Normal
import scipy.stats as stats
from scipy.stats import chi2

# %load_ext autoreload
# %autoreload 2

# %%
#vae latent dimension
latent_dim = 2

def get_ind(id, df):
    return np.where(df['patient_id'] == id)[0]

def get_design_matrix(df_effects, fixed_effects_keys, random_effects_keys, r=1, include_interaction=False):
    patient_id = df_effects['patient_id'].unique()

    X_list = [torch.from_numpy(np.array(df_effects.loc[get_ind(id, df_effects), fixed_effects_keys])).to(torch.float32) for id in patient_id]

    if include_interaction==True:
        for key in random_effects_keys[1:]:
            X_list = [torch.cat((X_i, X_i[:,1:] * torch.from_numpy(np.array(df_effects.loc[get_ind(patient_id[j], df_effects), key])).unsqueeze(-1)
                                ), -1).to(torch.float32) for j,X_i in enumerate(X_list)]

    X_list = [torch.cat((torch.from_numpy(np.array(df_effects.loc[get_ind(patient_id[j], df_effects), 'age'])).unsqueeze(-1), X_i), -1).to(torch.float32) for j,X_i in enumerate(X_list)]


    Z_list = [torch.from_numpy(np.array(df_effects.loc[get_ind(id, df_effects), random_effects_keys])).to(torch.float32) for id in patient_id]
    Z_list = [torch.block_diag(*[i for j in range(r)]) for i in Z_list]   
    X_list = [torch.block_diag(*[i for j in range(r)]) for i in X_list]
    return X_list, Z_list

# %%
# initialize Encoder and Decoder Models and the Mixed Model Parameters. mode='diagonal': Diagonal Covariance Matrix, mode='full': Full Covariance Matrix,
def initialize(latent_dim, mode='diagonal'):
    encoder = Encoder(
        input_dim=69,
        hidden_dims=[150], 
        output_dim=latent_dim, 
        act=torch.nn.Tanh())

    decoder = Decoder(
        item_positions=np.concatenate([[i]*a for i,a in enumerate(np.array(test_scores_df[test_scores_df.columns[1:]].max(0)).astype(np.int32))]),                            
        input_dim=latent_dim,
        hidden_dims=[150], 
        act=torch.nn.Tanh())

    var_param = CovarianceMatrix(q*latent_dim, mode=mode)    
    return encoder, decoder, var_param

# %%
#Train the VAE model:  Weighting of the loss function
# alpha: kl-divergence weight;  
# delta: MSE distance between encoder prediction and decoder; 
# gamma: decoder reconstruction loss
# eta: mixed model loss

# batch_size should be greater than 50

def train_vae(epochs, batch_size, encoder, decoder, optimizer_vae, alpha=1, gamma=1):
    steps = int(len(test_scores_df_encoded) / batch_size)
    rng = np.random.default_rng(1234)
    prior = Normal(torch.zeros(torch.Size([latent_dim])), torch.ones(torch.Size([latent_dim])))
    #progBar = Progress_Bar(epochs, steps, ['nELBO', 'KL', 'Rec Loss', 'Item Error'])
    
    for epoch in range(epochs):
        shuffle = rng.permutation(len(test_scores_df_encoded))
        
        for step in range(steps):
            pat_batch = np.arange(len(test_scores_df_encoded))[shuffle[step*batch_size:(step+1)*batch_size]]

            test_data = torch.from_numpy(np.array(test_scores_df_encoded.loc[pat_batch])).to(torch.float32)
            test_data_orig = torch.from_numpy(np.array(test_scores_df[test_scores_df.columns[1:]].loc[pat_batch])).to(torch.int32)
            
            optimizer_vae.zero_grad(set_to_none=True)
            #encode test scores
            mu, log_sig = encoder.encode(test_data)

            #reparametrization trick to get latent variables
            eps = prior.sample(torch.Size([log_sig.size(dim=0)])) 
            z = mu + log_sig.exp() * eps
            
            #kl divergence
            kl = torch.mean(0.5 * torch.sum(mu.square() + torch.exp(2.0 * log_sig) - 1.0 - (2.0 * log_sig), dim=1))

            rec_loss, probs = decoder(z, test_data_orig)
            nelbo = alpha * kl + gamma * rec_loss
                
            nelbo.backward()
            optimizer_vae.step()

            #data_pred = torch.stack([torch.argmax(pred, dim=-1) for pred in probs]) 
            # total test item prediction error  
            #item_error = np.mean(np.sum(np.abs(data_pred.detach().numpy() - test_data_orig.T.numpy()), axis=0))

            # progBar.update({
            #     'nELBO': nelbo.item(), 
            #     'KL': alpha * kl.item(), 
            #     'Rec Loss': gamma * rec_loss.item(), 
            #     'Item Error': item_error,
            #     }) 
    
    with torch.no_grad():
        mu = encoder.encode(torch.from_numpy(np.array(test_scores_df_encoded)).to(torch.float32))[0] 
        return mu.detach()


def calc_likelihood(var_param, Z_list_batch, X_list_batch, z_list):
    Phi, sigma = var_param()
    N = sum([len(Z_i) for Z_i in Z_list_batch])

    V_list = [Z_i @ Phi @ Z_i.t() + torch.eye(Z_i.size(0)) * sigma for Z_i in Z_list_batch]
    V_inv_list = [V_i.inverse() for V_i in V_list]
    
    Xt_V_inv_X = torch.stack([X_i.t() @ V_i_inv @ X_i for X_i, V_i_inv in zip(X_list_batch, V_inv_list)]).sum(dim=0)
    Xt_V_inv_y = torch.stack([X_i.t() @ V_i_inv @ y_i for X_i, V_i_inv, y_i in zip(X_list_batch, V_inv_list, z_list)]).sum(dim=0)

    #Check if Xt_V_inv_X is invertible. Only needed for mini batching
    if torch.abs(torch.det(Xt_V_inv_X)) > 1e-6:
        EBLUE = Xt_V_inv_X.inverse() @ Xt_V_inv_y
        # EBLUP_list = [Phi @ Z_i.t() @ V_i_inv @ (y_i - X_i @ EBLUE) for X_i, Z_i, V_i_inv, y_i in zip(X_list_batch, Z_list_batch, V_inv_list, z_list)]

        residual_list = [y_i - X_i @ EBLUE for y_i, X_i in zip(z_list, X_list_batch)]
        #Mixed model prediction
        # z_pred = torch.cat([X_i @ EBLUE + Z_i @ EBLUP_i for X_i, Z_i, EBLUP_i in zip(X_list_batch, Z_list_batch, EBLUP_list)]).reshape((-1, latent_dim))

        log_det_V = torch.stack([V_i.det().clamp(min=1e-12).log() for V_i in V_list]).sum()
        const = torch.log(torch.tensor(2.0 * torch.pi))
        rt_V_inv_r = torch.stack([r_i.t() @ V_i_inv @ r_i for r_i, V_i_inv in zip(residual_list, V_inv_list)]).sum()

        #negative mixed models likelihood
        nML = 0.5 * (log_det_V + rt_V_inv_r + N * const) #/ N   
         
    return nML

def calc_likelihood_full_model(var_param, Z_list_batch, X_list_batch, z_list):
    Phi, sigma = var_param()

    V_list = [Z_i @ Phi @ Z_i.t() + torch.eye(Z_i.size(0)) * sigma for Z_i in Z_list_batch]
    V_inv_list = [V_i.inverse() for V_i in V_list]
            
    Xt_V_inv_X = torch.stack([X_i.t() @ V_i_inv @ X_i for X_i, V_i_inv in zip(X_list_batch, V_inv_list)]).sum(dim=0)
    Xt_V_inv_y = torch.stack([X_i.t() @ V_i_inv @ y_i for X_i, V_i_inv, y_i in zip(X_list_batch, V_inv_list, z_list)]).sum(dim=0)

    #Check if Xt_V_inv_X is invertible. Only needed for mini batching
    if torch.abs(torch.det(Xt_V_inv_X)) > 1e-6:
        EBLUE = Xt_V_inv_X.inverse() @ Xt_V_inv_y
        EBLUP_list = [Phi @ Z_i.t() @ V_i_inv @ (y_i - X_i @ EBLUE) for X_i, Z_i, V_i_inv, y_i in zip(X_list_batch, Z_list_batch, V_inv_list, z_list)]

        #Mixed model prediction
        z_pred = torch.cat([X_i @ EBLUE + Z_i @ EBLUP_i for X_i, Z_i, EBLUP_i in zip(X_list_batch, Z_list_batch, EBLUP_list)]).reshape((-1, latent_dim))
         
    return z_pred

def train_vae_2(epochs, batch_size, encoder, decoder, optimizer_vae, Z_list, X_list, var_param, alpha=1, gamma=1, eta=0.01):
    steps = int(num_patients / batch_size)
    rng = np.random.default_rng(1234)
    prior = Normal(torch.zeros(torch.Size([latent_dim])), torch.ones(torch.Size([latent_dim])))
    
    for epoch in range(epochs):
        shuffle = rng.permutation(num_patients)
        
        for step in range(steps):
            #draw minibatch
            pat_batch = patients[shuffle[step*batch_size:(step+1)*batch_size]]
            pat_ind_batch = [torch.arange(pat_ind[i],pat_ind[i+1]) for i in pat_batch]
            
            ind_batch = []
            add = 0
            for ind in range(len(pat_ind_batch)):
                len_i = len(pat_ind_batch[ind])
                ind_batch += [torch.arange(add, add + len_i)]
                add += len_i

            Z_list_batch = [Z_list[pat] for pat in pat_batch]
            X_list_batch = [X_list[pat] for pat in pat_batch]
            
            test_data = torch.concatenate([torch.from_numpy(np.array(test_scores_df_encoded.loc[ind])).to(torch.float32) for ind in pat_ind_batch])
            test_data_orig = torch.concatenate([torch.from_numpy(np.array(test_scores_df[test_scores_df.columns[1:]].loc[ind])).to(torch.int32) for ind in pat_ind_batch])
            
            optimizer_vae.zero_grad(set_to_none=True)
            #encode test scores
            mu, log_sig = encoder.encode(test_data)

            #reparametrization trick to get latent variables
            eps = prior.sample(torch.Size([log_sig.size(dim=0)]))
            z = mu + log_sig.exp() * eps
            
            #kl divergence
            kl = torch.mean(0.5 * torch.sum(mu.square() + torch.exp(2.0 * log_sig) - 1.0 - (2.0 * log_sig), dim=1))

            # get the response variable list (latent z)
            z_list = [z[ind].flatten().to(torch.float32) for ind in ind_batch]

            #Mixed model loglikelihood loss. Notation follows https://www.sfu.ca/sasdoc/sashtml/stat/chap41/sect23.htm
            Phi, sigma = var_param()

            V_list = [Z_i @ Phi @ Z_i.t() + torch.eye(Z_i.size(0)) * sigma for Z_i in Z_list_batch]
            V_inv_list = [V_i.inverse() for V_i in V_list]
            
            Xt_V_inv_X = torch.stack([X_i.t() @ V_i_inv @ X_i for X_i, V_i_inv in zip(X_list_batch, V_inv_list)]).sum(dim=0)
            Xt_V_inv_y = torch.stack([X_i.t() @ V_i_inv @ y_i for X_i, V_i_inv, y_i in zip(X_list_batch, V_inv_list, z_list)]).sum(dim=0)

            #Check if Xt_V_inv_X is invertible. Only needed for mini batching
            if torch.abs(torch.det(Xt_V_inv_X)) > 1e-6:
                EBLUE = Xt_V_inv_X.inverse() @ Xt_V_inv_y
                EBLUP_list = [Phi @ Z_i.t() @ V_i_inv @ (y_i - X_i @ EBLUE) for X_i, Z_i, V_i_inv, y_i in zip(X_list_batch, Z_list_batch, V_inv_list, z_list)]
        
                #Mixed model prediction
                z_pred = torch.cat([X_i @ EBLUE + Z_i @ EBLUP_i for X_i, Z_i, EBLUP_i in zip(X_list_batch, Z_list_batch, EBLUP_list)]).reshape((-1, latent_dim))


                #distance between encoder latent variables and mixed model prediction
                residuals = ((z_pred - z) ** 2).sum(1).mean()

                #reconstruction loss
                rec_loss, probs = decoder(z_pred, test_data_orig)
                nelbo = alpha * kl + eta * residuals + gamma * rec_loss
                
                nelbo.backward()
                optimizer_vae.step()
                
    with torch.no_grad():
        mu = encoder.encode(torch.from_numpy(np.array(test_scores_df_encoded)).to(torch.float32))[0] 
        return mu.detach()

# %%
def likelihood_ratio(L_full, L_red):
    return 2 * (L_full - L_red)

# %%
# RUN SIMULATION FOR n = num_simulations
num_simulations = 50

lrt_results_before = [] # List to save the results
lrt_results_after = []

all_epochs_dict = {} #dictionary to save all models in only one frame

fixed_effects_keys_full = ['family_affected', 'sco_surg', '≤3', 'onset_age', 'presym_diag', 'presymptomatic', 'stand_lost', 'stand_gained', 'stand_never', 'sex']
random_effects_keys_full = ['intercept', 'since_medication', 'since_switch']
# reduced model without fixed effect 'sex' 
fixed_effects_keys_red = ['family_affected', 'sco_surg', '≤3', 'onset_age', 'presym_diag', 'presymptomatic', 'stand_lost', 'stand_gained', 'stand_never']
random_effects_keys_red = ['intercept', 'since_medication', 'since_switch']

q = len(random_effects_keys_full)

for i in range(num_simulations):
    print('epoch', i)
    #Load dataframes: test_scores has high dimensional test score data of hfsme tests
    test_scores_df = pd.read_csv(os.getcwd()+'/test_scores.csv')

    #test_scores_df_encoded is a thermometer encoding of test_scores_df for the encoder network
    test_scores_df_encoded = thermometer_encode_df(test_scores_df, test_scores_df.columns[1:])

    #time_df contains data that changes with time, e.g.: age or time since medication switch
    time_df = pd.read_csv(os.getcwd()+'/time_df.csv')
    time_df['intercept'] = np.ones(time_df.shape[0])

    #baseline_df contains features that characterizes patients at baseline
    baseline_df = pd.read_csv(os.getcwd()+'/baseline_df.csv')

    # 'sex' has no influence:
    baseline_df['sex'] = np.random.randint(2, size=baseline_df.shape[0])

    df_effects = pd.merge(baseline_df, time_df, on='patient_id', how='inner')
    
    patients = torch.from_numpy(np.array(baseline_df['patient_id']))
    num_patients = len(patients)
    
    # get design matrix for the full model
    X_list_full, Z_list_full = get_design_matrix(df_effects, fixed_effects_keys_full, random_effects_keys_full, r=latent_dim)
    # get design matrix for the reduced model
    X_list_red, Z_list_red = get_design_matrix(df_effects, fixed_effects_keys_red, random_effects_keys_red, r=latent_dim)   
    
    pat_ind = np.cumsum([0]+[int(len(X_i)/latent_dim) for X_i in X_list_full])
    
    

    print('\n', i)
    # reinitialize the parameters and the optimizer
    encoder, decoder = initialize(latent_dim)[0:2]
    optimizer_vae = torch.optim.Adam([ 
        {'params': encoder.parameters(), 'lr': 0.01},  
        {'params': decoder.parameters(), 'lr': 0.01},  
    ])
    
    var_param_full = CovarianceMatrix(q*latent_dim, mode='diagonal')    
    var_param_red = CovarianceMatrix(q*latent_dim, mode='diagonal')    
    
    optimizer_mm_full = torch.optim.Adam([ 
        {'params': var_param_full.parameters(), 'lr': 1.0}
    ])

    optimizer_mm_red = torch.optim.Adam([ 
        {'params': var_param_red.parameters(), 'lr': 1.0}
    ])
    
    z = train_vae(150, 100, encoder, decoder, optimizer_vae)

    pat_ind_b = [torch.arange(pat_ind[i],pat_ind[i+1]) for i in patients]
    z_list = [z[ind].flatten().to(torch.float32) for ind in pat_ind_b]
    
    steps = 300
    #progBar_full = Progress_Bar(steps, 1, ['nML'])
    #progBar_red = Progress_Bar(steps, 1, ['nML'])

    print('\nTrain full:')
    for j in range(steps):
        optimizer_mm_full.zero_grad(set_to_none=True)
        nML_full = calc_likelihood(var_param_full, Z_list_full, X_list_full, z_list)
        nML_full.backward()
        optimizer_mm_full.step()       
        # progBar_full.update({
        #     'nML': nML_full.item(), 
        #     }) 

    print('\nTrain reduced:')
    for k in range(steps):
        optimizer_mm_red.zero_grad(set_to_none=True)
        nML_red = calc_likelihood(var_param_red, Z_list_red, X_list_red, z_list)
        nML_red.backward()
        optimizer_mm_red.step()            
        # progBar_red.update({
        #     'nML': nML_red.item(), 
        #     }) 

    print('\nLikelihood ratio:', likelihood_ratio(nML_full, nML_red))
    lrt_results_before.append(likelihood_ratio(nML_full, nML_red))

    
    var_param_full = CovarianceMatrix(q*latent_dim, mode='diagonal')    
    var_param_red = CovarianceMatrix(q*latent_dim, mode='diagonal')    
    
    optimizer_mm_full = torch.optim.Adam([ 
        {'params': var_param_full.parameters(), 'lr': 1.0}
    ])

    optimizer_mm_red = torch.optim.Adam([ 
        {'params': var_param_red.parameters(), 'lr': 1.0}
    ])
    
    print("\n2. Trainingsschritt")
    z_pred = calc_likelihood_full_model(var_param_full, Z_list_full, X_list_full, z_list)
    z = train_vae_2(50, 64, encoder, decoder, optimizer_vae, Z_list_full, X_list_full, var_param_full, alpha=1, gamma=1, eta=0.01)

    pat_ind_b = [torch.arange(pat_ind[i],pat_ind[i+1]) for i in patients]
    z_list = [z[ind].flatten().to(torch.float32) for ind in pat_ind_b]
    
    steps = 300
    #progBar_full = Progress_Bar(steps, 1, ['nML'])
    #progBar_red = Progress_Bar(steps, 1, ['nML'])

    print('\nTrain full after:')
    for j in range(steps):
        optimizer_mm_full.zero_grad(set_to_none=True)
        nML_full_after = calc_likelihood(var_param_full, Z_list_full, X_list_full, z_list)
        nML_full_after.backward()
        optimizer_mm_full.step()
        # progBar_full.update({
        #     'nML': nML_full.item(), 
        #     }) 

    print('\nTrain reduced after:')
    for k in range(steps):
        optimizer_mm_red.zero_grad(set_to_none=True)
        nML_red_after = calc_likelihood(var_param_red, Z_list_red, X_list_red, z_list)
        nML_red_after.backward()
        optimizer_mm_red.step()
        # progBar_red.update({
        #     'nML': nML_red.item(), 
        #     }) 
    
    # all_epochs_dict[f'epoch_{i}'] = {
    #     'encoder_state_dict': encoder.state_dict(),
    #     'decoder_state_dict': decoder.state_dict(),
    #     'var_param_full': var_param_full,
    #     'optimizer_vae_state_dict': optimizer_vae.state_dict(),
    #     'var_param_red': var_param_red,
    #     'optimizer_mm_full': optimizer_mm_full,
    #     'optimizer_mm_red': optimizer_mm_red,
    #     'X_list_full' : X_list_full,
    #     'Z_list_full' : Z_list_full,
    #     'X_list_red' : X_list_red,
    #     'Z_list_red' : Z_list_red,
    #     'z_list': z_list
    # }

    print('\nLikelihood ratio after:', likelihood_ratio(nML_full_after, nML_red_after))
    lrt_results_after.append(likelihood_ratio(nML_full_after, nML_red_after))

torch.save(all_epochs_dict, fr'C:\Users\yanni\OneDrive\Desktop\BachelorArbeit2024\Code\trained_models\vae_MM_getrennt_{num_simulations}_epochs.pth')
# Out:
# epoch 0
#
#  0
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-2.2812, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-1.5283, grad_fn=<MulBackward0>)
# epoch 1
#
#  1
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-5.9883, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-1.5000, grad_fn=<MulBackward0>)
# epoch 2
#
#  2
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.6484, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-6.7349, grad_fn=<MulBackward0>)
# epoch 3
#
#  3
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.6484, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.1787, grad_fn=<MulBackward0>)
# epoch 4
#
#  4
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.8906, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(0.0010, grad_fn=<MulBackward0>)
# epoch 5
#
#  5
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.2773, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.4365, grad_fn=<MulBackward0>)
# epoch 6
#
#  6
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-3.3027, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.0288, grad_fn=<MulBackward0>)
# epoch 7
#
#  7
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(0.0449, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.5181, grad_fn=<MulBackward0>)
# epoch 8
#
#  8
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.9336, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-24.6387, grad_fn=<MulBackward0>)
# epoch 9
#
#  9
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.1992, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.0840, grad_fn=<MulBackward0>)
# epoch 10
#
#  10
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.2344, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.2188, grad_fn=<MulBackward0>)
# epoch 11
#
#  11
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.1172, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.0059, grad_fn=<MulBackward0>)
# epoch 12
#
#  12
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-1.4121, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-36.9883, grad_fn=<MulBackward0>)
# epoch 13
#
#  13
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.7148, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-1.5742, grad_fn=<MulBackward0>)
# epoch 14
#
#  14
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-1.2852, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.5059, grad_fn=<MulBackward0>)
# epoch 15
#
#  15
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.2168, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.2729, grad_fn=<MulBackward0>)
# epoch 16
#
#  16
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.1973, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(24.2266, grad_fn=<MulBackward0>)
# epoch 17
#
#  17
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-1.4414, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-1.6084, grad_fn=<MulBackward0>)
# epoch 18
#
#  18
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.9502, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.1807, grad_fn=<MulBackward0>)
# epoch 19
#
#  19
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.3105, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.1147, grad_fn=<MulBackward0>)
# epoch 20
#
#  20
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-9., grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-20.8643, grad_fn=<MulBackward0>)
# epoch 21
#
#  21
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(0.0117, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.2993, grad_fn=<MulBackward0>)
# epoch 22
#
#  22
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.1709, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-25.3438, grad_fn=<MulBackward0>)
# epoch 23
#
#  23
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.5039, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.0586, grad_fn=<MulBackward0>)
# epoch 24
#
#  24
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.5977, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.1113, grad_fn=<MulBackward0>)
# epoch 25
#
#  25
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-5.8438, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.1016, grad_fn=<MulBackward0>)
# epoch 26
#
#  26
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.9727, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.1992, grad_fn=<MulBackward0>)
# epoch 27
#
#  27
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-1.8848, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-1.6084, grad_fn=<MulBackward0>)
# epoch 28
#
#  28
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.7861, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.2920, grad_fn=<MulBackward0>)
# epoch 29
#
#  29
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-8.4746, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(12.2305, grad_fn=<MulBackward0>)
# epoch 30
#
#  30
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-1.0723, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.3359, grad_fn=<MulBackward0>)
# epoch 31
#
#  31
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-3.8926, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.4409, grad_fn=<MulBackward0>)
# epoch 32
#
#  32
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.9844, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-12.1846, grad_fn=<MulBackward0>)
# epoch 33
#
#  33
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-1.7031, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.5850, grad_fn=<MulBackward0>)
# epoch 34
#
#  34
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-6.8418, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(27.5225, grad_fn=<MulBackward0>)
# epoch 35
#
#  35
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-4.6836, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(25.3193, grad_fn=<MulBackward0>)
# epoch 36
#
#  36
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.3066, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.2534, grad_fn=<MulBackward0>)
# epoch 37
#
#  37
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-2.6113, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.4072, grad_fn=<MulBackward0>)
# epoch 38
#
#  38
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.0488, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-15.2617, grad_fn=<MulBackward0>)
# epoch 39
#
#  39
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-4.2676, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-2.1641, grad_fn=<MulBackward0>)
# epoch 40
#
#  40
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-6.5117, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-4.1377, grad_fn=<MulBackward0>)
# epoch 41
#
#  41
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.3906, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-2.1230, grad_fn=<MulBackward0>)
# epoch 42
#
#  42
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-8.6094, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-2.6138, grad_fn=<MulBackward0>)
# epoch 43
#
#  43
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-2.3398, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-1.0684, grad_fn=<MulBackward0>)
# epoch 44
#
#  44
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-2.5117, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.4521, grad_fn=<MulBackward0>)
# epoch 45
#
#  45
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-4.5293, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-0.0552, grad_fn=<MulBackward0>)
# epoch 46
#
#  46
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-0.0127, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
#
# Train reduced after:
#
# Likelihood ratio after: tensor(-56.1074, grad_fn=<MulBackward0>)
# epoch 47
#
#  47
#
# Train full:
#
# Train reduced:
#
# Likelihood ratio: tensor(-1.1855, grad_fn=<MulBackward0>)
#
# 2. Trainingsschritt
#
# Train full after:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[12], line 126
#     124 for j in range(steps):
#     125     optimizer_mm_full.zero_grad(set_to_none=True)
# --> 126     nML_full_after = calc_likelihood(var_param_full, Z_list_full, X_list_full, z_list)
#     127     nML_full_after.backward()
#     128     optimizer_mm_full.step()
#
# Cell In[5], line 83, in calc_likelihood(var_param, Z_list_batch, X_list_batch, z_list)
#      80     #negative mixed models likelihood
#      81     nML = 0.5 * (log_det_V + rt_V_inv_r + N * const) #/ N
# ---> 83 return nML
#
# UnboundLocalError: local variable 'nML' referenced before assignment

# %%
# plot the histogr<am of the LRT-statistic
plt.hist(np.array(torch.stack(lrt_results_after).detach()), bins=50, density=True, alpha=0.6, color='g')
# x = np.linspace(-8000, 8000, 100)
# plt.plot(x, chi2.pdf(x + 500, df=1), 'r-', lw=2, label='Chi-Quadrat-Verteilung (df=1)')

x = np.linspace(0, 10, 100)
plt.plot(-x, chi2.pdf(x, df=1), 'r-', lw=1, label='Chi-Squared (df=1)')

# Beschriftungen hinzufügen
plt.title('Histogramm der Likelihood-Ratio-Teststatistiken')
plt.xlabel('Teststatistik')
plt.ylabel('Häufigkeit')
plt.legend()

# Histogramm anzeigen
plt.show()

# %%
plt.hist(np.array(torch.stack(lrt_results_before).detach()), bins=50, density=True, alpha=0.6, color='b')


x = np.linspace(0, 10, 100)
plt.plot(-x, chi2.pdf(x, df=1), 'r-', lw=1, label='Chi-Squared (df=1)')

# Beschriftungen hinzufügen
plt.title('Histogramm der Likelihood-Ratio-Teststatistiken')
plt.xlabel('Teststatistik')
plt.ylabel('Häufigkeit')
plt.legend()

# Histogramm anzeigen
plt.show()
